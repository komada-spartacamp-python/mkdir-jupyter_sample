# %%
import matplotlib.pyplot as plt

# %%
plt.plot([11,22,33,44])

# %%
plt.plot([11,22,33,44],[23,34,45,56])

# %%
import numpy as np

# %%
x = np.array([11,22,33,44])

# %%
plt.plot(x,x)

# %%
plt.plot(x,x,label="r--")
plt.plot(x,x**2,label="s")
plt.plot(x,x**3,label="g^")
plt.legend()

# %%
import pandas as pd
df = pd.read_csv("sample_data_01.csv")

# %%
plt.scatter(df["コンビニ数"],df["県民取得"])
plt.xlabel("C")
plt.ylabel("P")
# Out:
# Text(0, 0.5, 'P')
